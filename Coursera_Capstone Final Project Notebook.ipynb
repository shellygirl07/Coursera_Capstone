# %% [markdown]
# # Capstone Project: Office Supplier Expansion - New Location Data Analysis
#
# ## Introduction
#
# ### Background and Description of the Problem

# %% [markdown]
# The client is an  Office Supplier in Toronto which services  small to medium offices. They have saturated the market in their own area and are now looking to expand into a nearby city. The two options under consideration by the client are Quebec and Montreal. As this is will be the client’s first business expansion, it is important that out of the two possible locations, they choose the city offering the best possible outcome.
#
# During this process another aspect of the clients business should also be taken into consideration. This is the fact that potential customers expect delivery within the hour, so any business location would have to be close to a number of customer sites.
#
# The data science problem can be described using the  following questions:
#
# Part One: Which out of two possible locations has the greater number of potential customers?
#
# Part Two: In the city chosen in answer to part one, which city borough would offer the greatest catchment area for the business?

# %% [markdown]
# ## Part One:
#
# ## Which out of two possible locations has the greater number of potential customers?
#
# ### Data Collection: Location option one - Quebec

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import types
import pandas as pd
import types
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# %% [markdown]
# Quebec borough information was scraped from wikipedia as a .csv file which was then imported as a pandas dataframe

# %%
# The code was removed by Watson Studio for sharing.

# %%
df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   Postal Code           Borough
# 0         G1J  La Cité-Limoilou
# 1         G8T      Les Rivières
# 2         G1V        Sainte-Foy
# 3         G1H      Charlesbourg
# 4         G1E          Beauport

# %%
df_data_1.shape
# Out:
# (6, 2)

# %% [markdown]
# importing all dependencies required

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests 
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# Geo data for Quebec Boroughs was imported as a .csv file.

# %%
# The code was removed by Watson Studio for sharing.

# %%
df_geo = pd.read_csv(body)
df_geo.head()
# Out:
#   Postal Code  Longitude   Latitude
# 0         G1J  -71.21341  46.834900
# 1         G8T  -71.30556  46.830556
# 2         G1V  -71.28764  46.778570
# 3         G1H  -71.25796  46.852680
# 4         G1E  -71.19266  46.858510

# %% [markdown]
# The two dataframes were merged.

# %%
df_quebec= pd.merge(df_data_1, df_geo, on='Postal Code', how='left')
df_quebec.head()
# Out:
#   Postal Code           Borough  Longitude   Latitude
# 0         G1J  La Cité-Limoilou  -71.21341  46.834900
# 1         G8T      Les Rivières  -71.30556  46.830556
# 2         G1V        Sainte-Foy  -71.28764  46.778570
# 3         G1H      Charlesbourg  -71.25796  46.852680
# 4         G1E          Beauport  -71.19266  46.858510

# %% [markdown]
# Using geopy library to get the latitude and longitude values of Quebec

# %%
address = 'Quebec, Quebec, Canada'

geolocator = Nominatim(user_agent="quebec_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Quebec are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Quebec are 46.8259601, -71.2352226.

# %% [markdown]
# Creating a map of Quebec with neighbourhoods superimposed on top.

# %%
map_quebec = folium.Map(location=[latitude, longitude], zoom_start=10)

quebec = df_quebec

for lat, lng, borough in zip(quebec['Latitude'], quebec['Longitude'], quebec['Borough']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_quebec)  
    
map_quebec
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Using the foursquare API a search was made for potential clients using foursquare's office category. This was set within a five mile radius of the centre of Quebec.

# %%
# The code was removed by Watson Studio for sharing.

# %%
LIMIT = 100

radius = 8046

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId=4bf58dd8d48988d124941735'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d050885dd57972e8c4e5e49'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b59ff44f964a520a7a628e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b59ff44f964a520a7a628e3',
#        'location': {'address': '6655 boulevard Pierre-Bertrand',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'Boulevard Lebourgneuf',
#         'distance': 1570,
#         'formattedAddress': ['6655 boulevard Pierre-Bertrand (Boulevard Lebourgneuf)',
#          'Quebec QC G2K 1M1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.814336214973146,
#           'lng': -71.22354511608836}],
#         'lat': 46.814336214973146,
#         'lng': -71.22354511608836,
#         'postalCode': 'G2K 1M1',
#         'state': 'QC'},
#        'name': 'Absolu',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b643189f964a5206ca32ae3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b643189f964a5206ca32ae3',
#        'location': {'address': '410, boul. Charest Est',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'Rue de la Couronne',
#         'distance': 1572,
#         'formattedAddress': ['410, boul. Charest Est (Rue de la Couronne)',
#          'Québec QC',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.813975084261436,
#           'lng': -71.22430030226596}],
#         'lat': 46.813975084261436,
#         'lng': -71.22430030226596,
#         'state': 'QC'},
#        'name': 'Le Soleil',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c03aba00d0e0f47f3d6029a-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4c03aba00d0e0f47f3d6029a',
#        'location': {'address': '410, Boulevard Charest Est',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'De la Couronne',
#         'distance': 1575,
#         'formattedAddress': ['410, Boulevard Charest Est (De la Couronne)',
#          'Québec QC',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.813937659024894,
#           'lng': -71.2243111628315}],
#         'lat': 46.813937659024894,
#         'lng': -71.2243111628315,
#         'state': 'QC'},
#        'name': 'CGI Québec',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5124ea62e4b0d33c3fc81684-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '5124ea62e4b0d33c3fc81684',
#        'location': {'address': '683, rue Saint-Joseph Est\u2028, bureau 150',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 1602,
#         'formattedAddress': ['683, rue Saint-Joseph Est\u2028, bureau 150',
#          'Québec QC G1K 3C1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81532413654619,
#           'lng': -71.2210390172519}],
#         'lat': 46.81532413654619,
#         'lng': -71.2210390172519,
#         'postalCode': 'G1K 3C1',
#         'state': 'QC'},
#        'name': "Festival d'été de Québec - siège social",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ebbdad577c8d9bd1bb3b1d5-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ebbdad577c8d9bd1bb3b1d5',
#        'location': {'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 1643,
#         'formattedAddress': ['Québec QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81206745147222,
#           'lng': -71.22793849234718}],
#         'lat': 46.81206745147222,
#         'lng': -71.22793849234718,
#         'state': 'QC'},
#        'name': 'CSN Conseil Central Québec',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b910b04f964a5208ea033e3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b910b04f964a5208ea033e3',
#        'location': {'address': 'Boul. Charest est',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 1647,
#         'formattedAddress': ['Boul. Charest est', 'Québec QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81175708776541,
#           'lng': -71.22916481180975}],
#         'lat': 46.81175708776541,
#         'lng': -71.22916481180975,
#         'state': 'QC'},
#        'name': 'CLD de Quebec',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f3517a7e4b0cd0fe7f79a0e-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4f3517a7e4b0cd0fe7f79a0e',
#        'location': {'address': '585 boulevard Charest Est, 8e étage',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'de la Chapelle',
#         'distance': 1652,
#         'formattedAddress': ['585 boulevard Charest Est, 8e étage (de la Chapelle)',
#          'Québec QC G1K 2Z7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.8141372941683,
#           'lng': -71.22210579167428}],
#         'lat': 46.8141372941683,
#         'lng': -71.22210579167428,
#         'postalCode': 'G1K 2Z7',
#         'state': 'QC'},
#        'name': 'lg2',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ebbc514b634c5f6589b8597-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ebbc514b634c5f6589b8597',
#        'location': {'address': '400 Bélanger',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2071,
#         'formattedAddress': ['400 Bélanger', 'Québec QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81872513059751,
#           'lng': -71.26027702938792}],
#         'lat': 46.81872513059751,
#         'lng': -71.26027702938792,
#         'state': 'QC'},
#        'name': 'Manoir Sully résidence',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b82bc60f964a52046e130e3-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b82bc60f964a52046e130e3',
#        'location': {'address': "930 d'Aiguillon",
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2114,
#         'formattedAddress': ["930 d'Aiguillon", 'Quebec QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81277736631098,
#           'lng': -71.21524590236916}],
#         'lat': 46.81277736631098,
#         'lng': -71.21524590236916,
#         'state': 'QC'},
#        'name': 'Bell (Quebec City Offices)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bacebb5f964a520c5193be3-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4bacebb5f964a520c5193be3',
#        'location': {'address': '888 Rue Saint-Jean',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'Honoré Mercier',
#         'distance': 2146,
#         'formattedAddress': ['888 Rue Saint-Jean (Honoré Mercier)',
#          'Quebec QC G1R 1R1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81192273401208,
#           'lng': -71.21589911567125}],
#         'lat': 46.81192273401208,
#         'lng': -71.21589911567125,
#         'postalCode': 'G1R 1R1',
#         'state': 'QC'},
#        'name': 'Société Radio Canada // CBC',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eeb71ecc2ee434b714a90bf-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4eeb71ecc2ee434b714a90bf',
#        'location': {'address': '525, boul. René-Lévesque Est',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2329,
#         'formattedAddress': ['525, boul. René-Lévesque Est',
#          'Québec QC G1R 5S9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.8082491532788,
#           'lng': -71.2189390178286}],
#         'lat': 46.8082491532788,
#         'lng': -71.2189390178286,
#         'postalCode': 'G1R 5S9',
#         'state': 'QC'},
#        'name': 'Commission de la capitale nationale du Québec',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33346408'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50851c56e4b03db177cf9922-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '50851c56e4b03db177cf9922',
#        'location': {'address': '625, rue Saint-Amable',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2515,
#         'formattedAddress': ['625, rue Saint-Amable',
#          'Québec QC G1R 2G5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.8071809855264,
#           'lng': -71.2168554483802}],
#         'lat': 46.8071809855264,
#         'lng': -71.2168554483802,
#         'postalCode': 'G1R 2G5',
#         'state': 'QC'},
#        'name': 'La Capitale Groupe Financier - Siège Social',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ebd98a05c5c2798331f2c7f-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ebd98a05c5c2798331f2c7f',
#        'location': {'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2730,
#         'formattedAddress': ['Quebec QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.816015362334824,
#           'lng': -71.20246054530045}],
#         'lat': 46.816015362334824,
#         'lng': -71.20246054530045,
#         'state': 'QC'},
#        'name': 'Ex Machina',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f70e193121dff7da69a160b-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4f70e193121dff7da69a160b',
#        'location': {'address': '301-820, rue de Nemours',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2737,
#         'formattedAddress': ['301-820, rue de Nemours',
#          'Québec QC G1H 7B3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.85039430862781,
#           'lng': -71.23925568499759}],
#         'lat': 46.85039430862781,
#         'lng': -71.23925568499759,
#         'postalCode': 'G1H 7B3',
#         'state': 'QC'},
#        'name': 'Francis Bouchard Photographe',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '48763720'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c2bbf4f2219c9284216a548-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4c2bbf4f2219c9284216a548',
#        'location': {'address': '450, av Béchard',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2762,
#         'formattedAddress': ['450, av Béchard', 'Québec QC G1M 2E9', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81675707150115,
#           'lng': -71.2689065188319}],
#         'lat': 46.81675707150115,
#         'lng': -71.2689065188319,
#         'postalCode': 'G1M 2E9',
#         'state': 'QC'},
#        'name': 'Journal de Québec (Le)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c3ce0b3933b0f47bdace421-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4c3ce0b3933b0f47bdace421',
#        'location': {'address': '1173 blvd. Charest O',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'near ave. St-Sacrement',
#         'distance': 3174,
#         'formattedAddress': ['1173 blvd. Charest O (near ave. St-Sacrement)',
#          'Québec QC G1N 2C9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.80024553589252,
#           'lng': -71.25322717845883}],
#         'lat': 46.80024553589252,
#         'lng': -71.25322717845883,
#         'postalCode': 'G1N 2C9',
#         'state': 'QC'},
#        'name': 'Affluences',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '69363944'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d303886789a8cfa18aa2cc6-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4d303886789a8cfa18aa2cc6',
#        'location': {'address': '720 rue des Rocailles',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 3367,
#         'formattedAddress': ['720 rue des Rocailles',
#          'Québec QC G2J 1A5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.83719938532822,
#           'lng': -71.27627453813885}],
#         'lat': 46.83719938532822,
#         'lng': -71.27627453813885,
#         'postalCode': 'G2J 1A5',
#         'state': 'QC'},
#        'name': 'Reseau de Transport de la Capitale (RTC)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c5ffc1790b2c9b648ac3b22-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4c5ffc1790b2c9b648ac3b22',
#        'location': {'address': '325 rue du Marais',
#         'cc': 'CA',
#         'city': 'Vanier',
#         'country': 'Canada',
#         'distance': 3413,
#         'formattedAddress': ['325 rue du Marais', 'Vanier QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.82906376748802,
#           'lng': -71.27981018371094}],
#         'lat': 46.82906376748802,
#         'lng': -71.27981018371094,
#         'state': 'QC'},
#        'name': 'Piranha Quebec',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '47561462'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58efa9a6829b0c5ab06370ec-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '58efa9a6829b0c5ab06370ec',
#        'location': {'address': '330-1200 Rue des Soeurs-du-Bon-Pasteur,',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 3450,
#         'formattedAddress': ['330-1200 Rue des Soeurs-du-Bon-Pasteur,',
#          'Ville de Québec QC G1S 0B1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.79691595794427,
#           'lng': -71.25103712081909}],
#         'lat': 46.79691595794427,
#         'lng': -71.25103712081909,
#         'postalCode': 'G1S 0B1',
#         'state': 'QC'},
#        'name': 'Santé Podiatres',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '421316210'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fff0d43e0e2ec7c14651282-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4fff0d43e0e2ec7c14651282',
#        'location': {'address': '455, rue du Marais, bur. 210',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'rue Godin',
#         'distance': 3677,
#         'formattedAddress': ['455, rue du Marais, bur. 210 (rue Godin)',
#          'Québec QC G1M 3A2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.82763054690262,
#           'lng': -71.283438205719}],
#         'lat': 46.82763054690262,
#         'lng': -71.283438205719,
#         'postalCode': 'G1M 3A2',
#         'state': 'QC'},
#        'name': 'ALPHA Assurances',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b798104f964a52043fd2ee3-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b798104f964a52043fd2ee3',
#        'location': {'address': '1305, chemin Sainte-Foy',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'At Holland',
#         'distance': 3697,
#         'formattedAddress': ['1305, chemin Sainte-Foy (At Holland)',
#          'Québec QC G1S 4Y5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.795138370744,
#           'lng': -71.25331918425498}],
#         'lat': 46.795138370744,
#         'lng': -71.25331918425498,
#         'postalCode': 'G1S 4Y5',
#         'state': 'QC'},
#        'name': 'FM93',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59cab8eb0fe7a0355604936f-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '59cab8eb0fe7a0355604936f',
#        'location': {'address': '6580 Av Courvoisier',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 3769,
#         'formattedAddress': ['6580 Av Courvoisier',
#          'Québec QC G1H 5Y4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.85112146809858,
#           'lng': -71.26834271799453}],
#         'lat': 46.85112146809858,
#         'lng': -71.26834271799453,
#         'postalCode': 'G1H 5Y4',
#         'state': 'QC'},
#        'name': 'Isabelle Roy, agente en assurance de dommages',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b44d910f964a5200bfe25e3-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b44d910f964a5200bfe25e3',
#        'location': {'address': '1080, Grande Allée Ouest',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'Thornhill',
#         'distance': 3851,
#         'formattedAddress': ['1080, Grande Allée Ouest (Thornhill)',
#          'Québec QC G1K 7M3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.79196120725599,
#           'lng': -71.24456255815706}],
#         'lat': 46.79196120725599,
#         'lng': -71.24456255815706,
#         'postalCode': 'G1K 7M3',
#         'state': 'QC'},
#        'name': 'Industrielle Alliance',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '63161220'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf2f51798ac0f47b65662a8-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4bf2f51798ac0f47b65662a8',
#        'location': {'address': '1134, Grande Allée O',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 3983,
#         'formattedAddress': ['1134, Grande Allée O',
#          'Québec QC G1S 1E5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.79069245105441,
#           'lng': -71.24409137459446}],
#         'lat': 46.79069245105441,
#         'lng': -71.24409137459446,
#         'postalCode': 'G1S 1E5',
#         'state': 'QC'},
#        'name': 'CHOI Radio X - CHXX Radio X2',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-522074d28bbd37d7f96bbe87-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '522074d28bbd37d7f96bbe87',
#        'location': {'address': '2014 Rue Richer',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'Avenue Émile Côté',
#         'distance': 4483,
#         'formattedAddress': ['2014 Rue Richer (Avenue Émile Côté)',
#          'Québec QC G1V 1P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.791994707115535,
#           'lng': -71.2668514251709}],
#         'lat': 46.791994707115535,
#         'lng': -71.2668514251709,
#         'postalCode': 'G1V 1P1',
#         'state': 'QC'},
#        'name': 'Sublime Architecture',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '69463807'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4beb1806415e20a1c7e0e5bb-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4beb1806415e20a1c7e0e5bb',
#        'location': {'address': '2136 ch. Ste-Foy',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'at ave. Myrand',
#         'distance': 4902,
#         'formattedAddress': ['2136 ch. Ste-Foy (at ave. Myrand)',
#          'Québec QC G1V 1R8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.78906002995318,
#           'lng': -71.27034098195344}],
#         'lat': 46.78906002995318,
#         'lng': -71.27034098195344,
#         'postalCode': 'G1V 1R8',
#         'state': 'QC'},
#        'name': 'SOM  (Ste-Foy)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cfd563ad7206ea8fea14869-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4cfd563ad7206ea8fea14869',
#        'location': {'address': '950, avenue Galilee',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 5347,
#         'formattedAddress': ['950, avenue Galilee',
#          'Québec QC G1P 4B7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.80369137122634,
#           'lng': -71.2974227953708}],
#         'lat': 46.80369137122634,
#         'lng': -71.2974227953708,
#         'postalCode': 'G1P 4B7',
#         'state': 'QC'},
#        'name': 'Sobeys Quebec Inc.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-530f329611d20da25040da1e-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '530f329611d20da25040da1e',
#        'location': {'address': '150 des Commandeurs',
#         'cc': 'CA',
#         'city': 'Lévis',
#         'country': 'Canada',
#         'distance': 5629,
#         'formattedAddress': ['150 des Commandeurs', 'Lévis QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.803124,
#           'lng': -71.169284}],
#         'lat': 46.803124,
#         'lng': -71.169284,
#         'state': 'QC'},
#        'name': 'Desjardins',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc9133d3740b71393275e65-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4bc9133d3740b71393275e65',
#        'location': {'address': '2505 boulevard Laurier, bureau 200',
#         'cc': 'CA',
#         'city': 'Sainte-Foy',
#         'country': 'Canada',
#         'distance': 6583,
#         'formattedAddress': ['2505 boulevard Laurier, bureau 200',
#          'Sainte-Foy QC G1T 1R9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.773557531339875,
#           'lng': -71.27526215940975}],
#         'lat': 46.773557531339875,
#         'lng': -71.27526215940975,
#         'postalCode': 'G1T 1R9',
#         'state': 'QC'},
#        'name': 'Groupe Le Massif',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4de8dc44fa76fd1168aa6af9-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4de8dc44fa76fd1168aa6af9',
#        'location': {'address': '2525, Boul. Laurier',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'Autoroute Robert-Bourassa',
#         'distance': 6733,
#         'formattedAddress': ['2525, Boul. Laurier (Autoroute Robert-Bourassa)',
#          'Québec QC G1V 4H6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.77258560022573,
#           'lng': -71.27679382713998}],
#         'lat': 46.77258560022573,
#         'lng': -71.27679382713998,
#         'postalCode': 'G1V 4H6',
#         'state': 'QC'},
#        'name': 'SSQ Groupe Financier',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f29a540e4b018705312163f-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4f29a540e4b018705312163f',
#        'location': {'address': '2750 Einstein',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 6932,
#         'formattedAddress': ['2750 Einstein', 'Québec QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.79671221219423,
#           'lng': -71.31556026510238}],
#         'lat': 46.79671221219423,
#         'lng': -71.31556026510238,
#         'state': 'QC'},
#        'name': 'Parc Technologique de Quebec',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50c64dc239504db4ee3f77b8-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '50c64dc239504db4ee3f77b8',
#        'location': {'address': '1627, boul.Bastien',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 7250,
#         'formattedAddress': ['1627, boul.Bastien',
#          'Québec QC G2K 1H1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.85537827021525,
#           'lng': -71.32017374038696}],
#         'lat': 46.85537827021525,
#         'lng': -71.32017374038696,
#         'postalCode': 'G2K 1H1',
#         'state': 'QC'},
#        'name': 'Les Promotions André Pageau & P.A.P Communication',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '45537008'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c640366de1b2d7fb718e670-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4c640366de1b2d7fb718e670',
#        'location': {'address': '1405 boulevard du parc technologique',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 7298,
#         'formattedAddress': ['1405 boulevard du parc technologique',
#          'Québec QC g1p4p5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.80240125379232,
#           'lng': -71.32462385729053}],
#         'lat': 46.80240125379232,
#         'lng': -71.32462385729053,
#         'postalCode': 'g1p4p5',
#         'state': 'QC'},
#        'name': 'Thales Québec',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-518a417c498e5a9ef93b6347-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '518a417c498e5a9ef93b6347',
#        'location': {'address': '25 Glinel',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 7334,
#         'formattedAddress': ['25 Glinel', 'Québec QC G1B 3C5', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.890916,
#           'lng': -71.219043}],
#         'lat': 46.890916,
#         'lng': -71.219043,
#         'postalCode': 'G1B 3C5',
#         'state': 'QC'},
#        'name': 'Web Québec',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '55640932'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50928bc46ebbfab4f688d8d3-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '50928bc46ebbfab4f688d8d3',
#        'location': {'address': '2828 Boul Laurier Suite 700',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 7670,
#         'formattedAddress': ['2828 Boul Laurier Suite 700',
#          'Quebec QC G1V 0B9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.76795795214902,
#           'lng': -71.28955793780786}],
#         'lat': 46.76795795214902,
#         'lng': -71.28955793780786,
#         'postalCode': 'G1V 0B9',
#         'state': 'QC'},
#        'name': 'Regus',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e582ce114954ed283361c94-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d174941735',
#          'name': 'Coworking Space',
#          'pluralName': 'Coworking Spaces',
#          'primary': True,
#          'shortName': 'Coworking Space'}],
#        'id': '4e582ce114954ed283361c94',
#        'location': {'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2977,
#         'formattedAddress': ['Québec QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.836882247852905,
#           'lng': -71.27090434297901}],
#         'lat': 46.836882247852905,
#         'lng': -71.27090434297901,
#         'state': 'QC'},
#        'name': 'FTQ Bureau Régional de Québec',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f6108cbe4b071dd72b4bddd-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d174941735',
#          'name': 'Coworking Space',
#          'pluralName': 'Coworking Spaces',
#          'primary': True,
#          'shortName': 'Coworking Space'}],
#        'id': '4f6108cbe4b071dd72b4bddd',
#        'location': {'address': '925 Grande Allée Ouest, Quebec City, QC G1S 2L1',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 3538,
#         'formattedAddress': ['925 Grande Allée Ouest, Quebec City, QC G1S 2L1',
#          'Quebec City QC G1S 2L1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.794184527965434,
#           'lng': -71.23630984565253}],
#         'lat': 46.794184527965434,
#         'lng': -71.23630984565253,
#         'postalCode': 'G1S 2L1',
#         'state': 'QC'},
#        'name': 'Industrielle Alliance Auto & Habitation.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50102f70e4b0d4f3f383c13c-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d125941735',
#          'name': 'Tech Startup',
#          'pluralName': 'Tech Startups',
#          'primary': True,
#          'shortName': 'Tech Startup'}],
#        'id': '50102f70e4b0d4f3f383c13c',
#        'location': {'address': '300-265 rue de la Couronne',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 1278,
#         'formattedAddress': ['300-265 rue de la Couronne',
#          'Québec QC G1K 6E1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81636103958433,
#           'lng': -71.2260136528135}],
#         'lat': 46.81636103958433,
#         'lng': -71.2260136528135,
#         'postalCode': 'G1K 6E1',
#         'state': 'QC'},
#        'name': 'Savoir-faire Linux',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd4606b886cb60cfcbc7d89-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d125941735',
#          'name': 'Tech Startup',
#          'pluralName': 'Tech Startups',
#          'primary': True,
#          'shortName': 'Tech Startup'}],
#        'id': '4cd4606b886cb60cfcbc7d89',
#        'location': {'address': '305 Charest est, 9e étage',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 1614,
#         'formattedAddress': ['305 Charest est, 9e étage',
#          'Québec QC G1K 3H3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.81305783482096,
#           'lng': -71.22553395661005}],
#         'lat': 46.81305783482096,
#         'lng': -71.22553395661005,
#         'postalCode': 'G1K 3H3',
#         'state': 'QC'},
#        'name': 'Zengo',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-507c0e29e4b01b417b95d343-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d174941735',
#          'name': 'Coworking Space',
#          'pluralName': 'Coworking Spaces',
#          'primary': True,
#          'shortName': 'Coworking Space'}],
#        'id': '507c0e29e4b01b417b95d343',
#        'location': {'address': '6125, Wilfrid-Carrier',
#         'cc': 'CA',
#         'city': 'Lévis',
#         'country': 'Canada',
#         'distance': 7407,
#         'formattedAddress': ['6125, Wilfrid-Carrier', 'Lévis QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.79001424428538,
#           'lng': -71.15340041920186}],
#         'lat': 46.79001424428538,
#         'lng': -71.15340041920186,
#         'state': 'QC'},
#        'name': 'Desjardins',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd30b49a61c46881664b128-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/design_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f4941735',
#          'name': 'Design Studio',
#          'pluralName': 'Design Studios',
#          'primary': True,
#          'shortName': 'Design'}],
#        'id': '4cd30b49a61c46881664b128',
#        'location': {'address': '1200 Blvd St-Jean-Baptiste',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'crossStreet': 'Hamel',
#         'distance': 7550,
#         'formattedAddress': ['1200 Blvd St-Jean-Baptiste (Hamel)',
#          'Québec QC G2E 5E8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.801142321878324,
#           'lng': -71.32746135539475}],
#         'lat': 46.801142321878324,
#         'lng': -71.32746135539475,
#         'postalCode': 'G2E 5E8',
#         'state': 'QC'},
#        'name': 'Propage',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53444a7e11d2b7ce02343ceb-41',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a3d',
#          'name': 'Advertising Agency',
#          'pluralName': 'Advertising Agencies',
#          'primary': True,
#          'shortName': 'Advertising Agency'}],
#        'id': '53444a7e11d2b7ce02343ceb',
#        'location': {'address': '5100 Rue Des Tournelles, Bureau 239',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 3614,
#         'formattedAddress': ['5100 Rue Des Tournelles, Bureau 239',
#          'Québec QC G2J 1E4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.83563232421875,
#           'lng': -71.28053283691406}],
#         'lat': 46.83563232421875,
#         'lng': -71.28053283691406,
#         'postalCode': 'G2J 1E4',
#         'state': 'QC'},
#        'name': 'HD Marketing',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85487680'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b571ab6f964a5208f2628e3-42',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b571ab6f964a5208f2628e3',
#        'location': {'address': '444, Rue Bouvier, bureau 202',
#         'cc': 'CA',
#         'city': 'Québec',
#         'country': 'Canada',
#         'distance': 2886,
#         'formattedAddress': ['444, Rue Bouvier, bureau 202',
#          'Québec QC G2J 1E3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 46.83742884287205,
#           'lng': -71.26921945752319}],
#         'lat': 46.83742884287205,
#         'lng': -71.26921945752319,
#         'postalCode': 'G2J 1E3',
#         'state': 'QC'},
#        'name': 'CAA-Québec',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Québec',
#   'headerLocation': 'Québec',
#   'headerLocationGranularity': 'city',
#   'query': 'office',
#   'suggestedBounds': {'ne': {'lat': 46.89837417241407,
#     'lng': -71.12958521640469},
#    'sw': {'lat': 46.753546027585934, 'lng': -71.34085998359531}},
#   'totalResults': 43}}

# %% [markdown]
# The resulting .json file was normalized and imported into a pandas dataframe.

# %%
offices = results['response']['groups'][0]['items']
    
nearby_offices_quebec = json_normalize(offices) 

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_offices_quebec =nearby_offices_quebec.loc[:, filtered_columns]

nearby_offices_quebec['venue.categories'] = nearby_offices_quebec.apply(get_category_type, axis=1)

nearby_offices_quebec.columns = [col.split(".")[-1] for col in nearby_offices.columns]

nearby_offices_quebec.head()
# Out:
#                                       name categories        lat        lng
# 0                                   Absolu     Office  46.814336 -71.223545
# 1                                Le Soleil     Office  46.813975 -71.224300
# 2                               CGI Québec     Office  46.813938 -71.224311
# 3  Festival d'été de Québec - siège social     Office  46.815324 -71.221039
# 4               CSN Conseil Central Québec     Office  46.812067 -71.227938

# %%
nearby_offices_quebec.shape
# Out:
# (43, 4)

# %% [markdown]
# The resulting data frame show there are 43 potential customers within a five mile radius of the center of Quebec city.

# %% [markdown]
# ### Data Collection: Location option two - Montreal

# %% [markdown]
# The same process was then repeated with data for the city of Montreal

# %% [markdown]
# Montreal borough information was scraped from wikipedia as a .csv file which was then imported as a pandas dataframe

# %%
# The code was removed by Watson Studio for sharing.

# %%
df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#   Postal code                              Borough
# 0         H3M                Ahuntsic-Cartierville
# 1         H1K                                Anjou
# 2         H3W  Côte-des-Neiges–Notre-Dame-de-Grâce
# 3         H8S                              Lachine
# 4         H8N                              Lasalle

# %%
df_data_2.shape
# Out:
# (19, 2)

# %% [markdown]
# Geo data for Montreal Boroughs was imported as a .csv file.

# %%
# The code was removed by Watson Studio for sharing.

# %%
df_geo_montreal = pd.read_csv(body)
df_geo_montreal.head()
# Out:
#   Postal code  Latitude  Longitude
# 0         H3M  45.53856  -73.69266
# 1         H1K  45.60933  -73.54508
# 2         H3W  45.49069  -73.63321
# 3         H8S  45.43665  -73.68510
# 4         H8N  45.43890  -73.62583

# %% [markdown]
# The two dataframes were merged.

# %%
df_montreal= pd.merge(df_data_2, df_geo_montreal, on='Postal code', how='left')
df_montreal.head()
# Out:
#   Postal code                              Borough  Latitude  Longitude
# 0         H3M                Ahuntsic-Cartierville  45.53856  -73.69266
# 1         H1K                                Anjou  45.60933  -73.54508
# 2         H3W  Côte-des-Neiges–Notre-Dame-de-Grâce  45.49069  -73.63321
# 3         H8S                              Lachine  45.43665  -73.68510
# 4         H8N                              Lasalle  45.43890  -73.62583

# %% [markdown]
# Using geopy library to get the latitude and longitude values of Montreal

# %%
address = 'Montreal, Quebec, Canada'

geolocator = Nominatim(user_agent="montreal_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Montreal are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Montreal are 45.4972159, -73.6103642.

# %% [markdown]
# Creating a map of Montreal with neighbourhoods superimposed on top.

# %%
map_montreal = folium.Map(location=[latitude, longitude], zoom_start=10)

montreal = df_montreal

for lat, lng, borough in zip(montreal['Latitude'], montreal['Longitude'], montreal['Borough']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_montreal)  
    
map_montreal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Using the foursquare API a search was made for potential clients using foursquare's office category. This was set within a five mile radius of the centre of Montreal.

# %%
LIMIT = 200

radius = 8046

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId=4bf58dd8d48988d124941735'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d0508be4c1f672bccb6ab81'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c53143130f92d7f7ac433b8-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4c53143130f92d7f7ac433b8',
#        'location': {'address': '6250 rue Hutchison',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3141,
#         'formattedAddress': ['6250 rue Hutchison',
#          'Montréal QC H2V 4C5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52540441831818,
#           'lng': -73.61235213392237}],
#         'lat': 45.52540441831818,
#         'lng': -73.61235213392237,
#         'postalCode': 'H2V 4C5',
#         'state': 'QC'},
#        'name': 'Moment Factory',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af48901f964a5209af321e3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4af48901f964a5209af321e3',
#        'location': {'address': '1 Westmount Square',
#         'cc': 'CA',
#         'city': 'Westmount',
#         'country': 'Canada',
#         'crossStreet': 'entre Greene/St-Catherine/Wood/De Maisonneuve',
#         'distance': 2071,
#         'formattedAddress': ['1 Westmount Square (entre Greene/St-Catherine/Wood/De Maisonneuve)',
#          'Westmount QC H3Z 2A4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.48740505217079,
#           'lng': -73.58780703377471}],
#         'lat': 45.48740505217079,
#         'lng': -73.58780703377471,
#         'postalCode': 'H3Z 2A4',
#         'state': 'QC'},
#        'name': 'Westmount Square',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd0599d462cb713a324d807-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4bd0599d462cb713a324d807',
#        'location': {'address': '2101 St. Laurent Blvd.',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'Sherbrooke St. East',
#         'distance': 3676,
#         'formattedAddress': ['2101 St. Laurent Blvd. (Sherbrooke St. East)',
#          'Montréal QC H2X 2T5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.512104138012276,
#           'lng': -73.56829868117723}],
#         'lat': 45.512104138012276,
#         'lng': -73.56829868117723,
#         'postalCode': 'H2X 2T5',
#         'state': 'QC'},
#        'name': 'Just for Laughs Office',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0479a6f964a520775422e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b0479a6f964a520775422e3',
#        'location': {'address': '1350 boul. René-Lévesque Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'De La Montagne',
#         'distance': 3007,
#         'formattedAddress': ['1350 boul. René-Lévesque Ouest (De La Montagne)',
#          'Montréal QC H3G 1T4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.496315266809006,
#           'lng': -73.57184295883889}],
#         'lat': 45.496315266809006,
#         'lng': -73.57184295883889,
#         'postalCode': 'H3G 1T4',
#         'state': 'QC'},
#        'name': 'CGI',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad4c06cf964a520b7f920e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d130941735',
#          'name': 'Building',
#          'pluralName': 'Buildings',
#          'primary': True,
#          'shortName': 'Building'}],
#        'id': '4ad4c06cf964a520b7f920e3',
#        'location': {'address': '1 Place Ville Marie',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3274,
#         'formattedAddress': ['1 Place Ville Marie',
#          'Montréal QC H3B 2B6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.501459278555686,
#           'lng': -73.5688304901123}],
#         'lat': 45.501459278555686,
#         'lng': -73.5688304901123,
#         'postalCode': 'H3B 2B6',
#         'state': 'QC'},
#        'name': 'Place Ville Marie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ae74237f964a520cfa921e3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ae74237f964a520cfa921e3',
#        'location': {'address': '1155 Rue Metcalfe',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3208,
#         'formattedAddress': ['1155 Rue Metcalfe',
#          'Montréal QC H3B 2V6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.500158479718415,
#           'lng': -73.56945282817121}],
#         'lat': 45.500158479718415,
#         'lng': -73.56945282817121,
#         'postalCode': 'H3B 2V6',
#         'state': 'QC'},
#        'name': 'Édifice Sun Life',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56e9cf37498e8d07ac01d8f4-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '56e9cf37498e8d07ac01d8f4',
#        'location': {'address': '360 Saint Jacques',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4033,
#         'formattedAddress': ['360 Saint Jacques',
#          'Montréal QC H2Y 2N1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50239947219616,
#           'lng': -73.55920178694564}],
#         'lat': 45.50239947219616,
#         'lng': -73.55920178694564,
#         'postalCode': 'H2Y 2N1',
#         'state': 'QC'},
#        'name': 'Crew Collective & Cafe',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '185140064'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b3fabd3f964a520c5ab25e3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d121951735',
#          'name': 'Paper / Office Supplies Store',
#          'pluralName': 'Paper / Office Supplies Stores',
#          'primary': True,
#          'shortName': 'Office Supplies'}],
#        'id': '4b3fabd3f964a520c5ab25e3',
#        'location': {'address': '770 rue Notre-Dame Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'coin Duke',
#         'distance': 3892,
#         'formattedAddress': ['770 rue Notre-Dame Ouest (coin Duke)',
#          'Montréal QC H3C 1J5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49889527959269,
#           'lng': -73.5605357202378}],
#         'lat': 45.49889527959269,
#         'lng': -73.5605357202378,
#         'postalCode': 'H3C 1J5',
#         'state': 'QC'},
#        'name': 'Bureau en Gros',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57a1fa72498ef754ac40c539-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '57a1fa72498ef754ac40c539',
#        'location': {'address': '1067, Rue de Bleury',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'De la Gauchetière',
#         'distance': 3775,
#         'formattedAddress': ['1067, Rue de Bleury (De la Gauchetière)',
#          'Montréal QC H2Z 1N1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50452048526137,
#           'lng': -73.56311578607162}],
#         'lat': 45.50452048526137,
#         'lng': -73.56311578607162,
#         'postalCode': 'H2Z 1N1',
#         'state': 'QC'},
#        'name': 'La Finca – café & bureau',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55fc7557498e141bd5106ade-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a34',
#          'name': 'Community Center',
#          'pluralName': 'Community Centers',
#          'primary': True,
#          'shortName': 'Community Center'}],
#        'id': '55fc7557498e141bd5106ade',
#        'location': {'address': '550, rue Richmond',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'entre Notre-Dame & Lionel Groulx',
#         'distance': 3343,
#         'formattedAddress': ['550, rue Richmond (entre Notre-Dame & Lionel Groulx)',
#          'Montréal QC H3J 1V3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.48937535145937,
#           'lng': -73.5690067415223}],
#         'lat': 45.48937535145937,
#         'lng': -73.5690067415223,
#         'postalCode': 'H3J 1V3',
#         'state': 'QC'},
#        'name': 'Le Salon 1861',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5560b0a3498e157f860698b7-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5560b0a3498e157f860698b7',
#        'location': {'address': '4815-A Saint-Laurent',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'coin Villeneuve',
#         'distance': 3159,
#         'formattedAddress': ['4815-A Saint-Laurent (coin Villeneuve)',
#          'Montréal QC H2T 1R6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52164110524418,
#           'lng': -73.5897270318471}],
#         'lat': 45.52164110524418,
#         'lng': -73.5897270318471,
#         'postalCode': 'H2T 1R6',
#         'state': 'QC'},
#        'name': 'GAB',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c065bd2191f20a1f45ce414-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4c065bd2191f20a1f45ce414',
#        'location': {'address': '1755 rue René-Lévesque E',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'au niveau de la rue Papineau',
#         'distance': 5466,
#         'formattedAddress': ['1755 rue René-Lévesque E (au niveau de la rue Papineau)',
#          'Montréal QC H2K 4P6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52190008236958,
#           'lng': -73.54978283036978}],
#         'lat': 45.52190008236958,
#         'lng': -73.54978283036978,
#         'postalCode': 'H2K 4P6',
#         'state': 'QC'},
#        'name': 'RDS',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ced39d87b943704f0882553-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ced39d87b943704f0882553',
#        'location': {'address': '2001 McGill College',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'President-Kennedy',
#         'distance': 2978,
#         'formattedAddress': ['2001 McGill College (President-Kennedy)',
#          'Montréal QC',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.503894,
#           'lng': -73.573402}],
#         'lat': 45.503894,
#         'lng': -73.573402,
#         'state': 'QC'},
#        'name': 'Cohn & Wolfe Montréal',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52ef0ac011d28fb9fc9fbd63-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '52ef0ac011d28fb9fc9fbd63',
#        'location': {'address': '2000, rue Mansfield, Centre Manuvie, suite 700',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'coin De Maisonneuve',
#         'distance': 2909,
#         'formattedAddress': ['2000, rue Mansfield, Centre Manuvie, suite 700 (coin De Maisonneuve)',
#          'Montréal QC H3A 2Z4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50248770828699,
#           'lng': -73.57383988696776}],
#         'lat': 45.50248770828699,
#         'lng': -73.57383988696776,
#         'postalCode': 'H3A 2Z4',
#         'state': 'QC'},
#        'name': 'Chinese Visa Application Service Center',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d08e57b143cb60c88c77da6-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4d08e57b143cb60c88c77da6',
#        'location': {'address': '4950, Queen Mary Road, Suite 101',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 1880,
#         'formattedAddress': ['4950, Queen Mary Road, Suite 101',
#          'Montréal QC H3W 1X3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.4864981626953,
#           'lng': -73.62898641498626}],
#         'lat': 45.4864981626953,
#         'lng': -73.62898641498626,
#         'postalCode': 'H3W 1X3',
#         'state': 'QC'},
#        'name': 'CDEC Côte-des-Neiges/Notre-Dame-de-Grâce',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b9f8baff964a5205e2a37e3-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b9f8baff964a5205e2a37e3',
#        'location': {'address': '1411 rue Crescent',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'bureau 300',
#         'distance': 2693,
#         'formattedAddress': ['1411 rue Crescent (bureau 300)',
#          'Montréal QC H3G 2B3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49732371458825,
#           'lng': -73.57585081688933}],
#         'lat': 45.49732371458825,
#         'lng': -73.57585081688933,
#         'postalCode': 'H3G 2B3',
#         'state': 'QC'},
#        'name': 'Media Experts',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ce5410b834ba35de1e5981a-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ce5410b834ba35de1e5981a',
#        'location': {'address': '5410 Decarie Blvd',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 2261,
#         'formattedAddress': ['5410 Decarie Blvd', 'Montréal QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.48573781073241,
#           'lng': -73.63426981178475}],
#         'lat': 45.48573781073241,
#         'lng': -73.63426981178475,
#         'state': 'QC'},
#        'name': 'Insight',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ca35faeb0ff8cfadfb3b65e-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ca35faeb0ff8cfadfb3b65e',
#        'location': {'address': '1501 McGill College',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3084,
#         'formattedAddress': ['1501 McGill College',
#          'Montréal QC H3A 3M8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.502260513633814,
#           'lng': -73.57149541600026}],
#         'lat': 45.502260513633814,
#         'lng': -73.57149541600026,
#         'postalCode': 'H3A 3M8',
#         'state': 'QC'},
#        'name': 'EMC Montreal',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f29816de4b0acec388b92be-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4f29816de4b0acec388b92be',
#        'location': {'address': '3430 Avenue du Musée, Montreal, QC H3G 1K3',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 2383,
#         'formattedAddress': ['3430 Avenue du Musée, Montreal, QC H3G 1K3',
#          'Montréal QC H3G 1K3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49830136186559,
#           'lng': -73.57985159621147}],
#         'lat': 45.49830136186559,
#         'lng': -73.57985159621147,
#         'postalCode': 'H3G 1K3',
#         'state': 'QC'},
#        'name': 'Musée des beaux-arts de Montréal, Centre administratif',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b4f1beaf964a52078fa26e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b4f1beaf964a52078fa26e3',
#        'location': {'address': '1245 Sherbrooke West',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 2460,
#         'formattedAddress': ['1245 Sherbrooke West', 'Montréal QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.500197527769394,
#           'lng': -73.57911489006943}],
#         'lat': 45.500197527769394,
#         'lng': -73.57911489006943,
#         'state': 'QC'},
#        'name': 'Manuvie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e9c80e86da1cbe0b926f997-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4e9c80e86da1cbe0b926f997',
#        'location': {'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3274,
#         'formattedAddress': ['Montréal QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.496185637355254,
#           'lng': -73.56842831997746}],
#         'lat': 45.496185637355254,
#         'lng': -73.56842831997746,
#         'state': 'QC'},
#        'name': 'Evenko',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad794fdf964a5206b0c21e3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4ad794fdf964a5206b0c21e3',
#        'location': {'address': '2100, rue Drummond',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'at rue Sherbrooke O',
#         'distance': 2614,
#         'formattedAddress': ['2100, rue Drummond (at rue Sherbrooke O)',
#          'Montréal QC H3G 1X1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49998060312185,
#           'lng': -73.57708514687427}],
#         'lat': 45.49998060312185,
#         'lng': -73.57708514687427,
#         'postalCode': 'H3G 1X1',
#         'state': 'QC'},
#        'name': 'Cossette',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '54870831'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e1de1bc185089860b1e3fad-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4e1de1bc185089860b1e3fad',
#        'location': {'address': '400 Avenue Atlantic Suite 205',
#         'cc': 'CA',
#         'city': 'Outremont',
#         'country': 'Canada',
#         'distance': 3372,
#         'formattedAddress': ['400 Avenue Atlantic Suite 205',
#          'Outremont QC H2V 1A5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52721603303253,
#           'lng': -73.6163592338562}],
#         'lat': 45.52721603303253,
#         'lng': -73.6163592338562,
#         'postalCode': 'H2V 1A5',
#         'state': 'QC'},
#        'name': 'Defacto Interactif Head Office',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58189d9438fa3800e90db206-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '58189d9438fa3800e90db206',
#        'location': {'address': '2200 Stanley, 4th floor',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'at Sherbrooke',
#         'distance': 2694,
#         'formattedAddress': ['2200 Stanley, 4th floor (at Sherbrooke)',
#          'Montréal QC',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.500859,
#           'lng': -73.57622}],
#         'lat': 45.500859,
#         'lng': -73.57622,
#         'state': 'QC'},
#        'name': 'Electronic Arts',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d3ee033ae942d43c82aa09a-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4d3ee033ae942d43c82aa09a',
#        'location': {'address': '4652, rue Jeanne-Mance',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': '2e et 3e étages',
#         'distance': 2798,
#         'formattedAddress': ['4652, rue Jeanne-Mance (2e et 3e étages)',
#          'Montréal QC H2V 4J4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51816567409588,
#           'lng': -73.59054565429688}],
#         'lat': 45.51816567409588,
#         'lng': -73.59054565429688,
#         'postalCode': 'H2V 4J4',
#         'state': 'QC'},
#        'name': "L'Hirondelle",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b60ab26f964a52024f329e3-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b60ab26f964a52024f329e3',
#        'location': {'address': '215, rue St-Jacques',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4158,
#         'formattedAddress': ['215, rue St-Jacques',
#          'Montréal QC H2Y 1M6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.504329926991616,
#           'lng': -73.55804542330722}],
#         'lat': 45.504329926991616,
#         'lng': -73.55804542330722,
#         'postalCode': 'H2Y 1M6',
#         'state': 'QC'},
#        'name': 'Ogilvy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b7179a8f964a52096482de3-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b7179a8f964a52096482de3',
#        'location': {'address': '600 rue de la Gauchetière Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'Côte du Beaver Hall',
#         'distance': 3655,
#         'formattedAddress': ['600 rue de la Gauchetière Ouest (Côte du Beaver Hall)',
#          'Montréal QC H3B 4L8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.5018051857947,
#           'lng': -73.56397032737732}],
#         'lat': 45.5018051857947,
#         'lng': -73.56397032737732,
#         'postalCode': 'H3B 4L8',
#         'state': 'QC'},
#        'name': 'Raymond Chabot Grant Thornton',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59dcce371de7654d3a472f07-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '59dcce371de7654d3a472f07',
#        'location': {'address': '1100 - 900 Maisonneuve Blvd W',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 2956,
#         'formattedAddress': ['1100 - 900 Maisonneuve Blvd W',
#          'Montréal QC H3A 0A8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50178482133966,
#           'lng': -73.5730424057057}],
#         'lat': 45.50178482133966,
#         'lng': -73.5730424057057,
#         'neighborhood': 'Ville-Marie',
#         'postalCode': 'H3A 0A8',
#         'state': 'QC'},
#        'name': 'Maison Manuvie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b476546f964a520cf3026e3-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b476546f964a520cf3026e3',
#        'location': {'address': '3575, boul. St-Laurent',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'Prince Arthur',
#         'distance': 3523,
#         'formattedAddress': ['3575, boul. St-Laurent (Prince Arthur)',
#          'Montréal QC H2X 2T7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.514017732855656,
#           'lng': -73.5720893740654}],
#         'lat': 45.514017732855656,
#         'lng': -73.5720893740654,
#         'postalCode': 'H2X 2T7',
#         'state': 'QC'},
#        'name': 'Touché! PHD',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '43232399'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dd1525588778512443c278b-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4dd1525588778512443c278b',
#        'location': {'address': '2515, rue Delisle',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'coin Charlevoix',
#         'distance': 3005,
#         'formattedAddress': ['2515, rue Delisle (coin Charlevoix)',
#          'Montréal QC H3J 1K8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.48364264983643,
#           'lng': -73.57706914908198}],
#         'lat': 45.48364264983643,
#         'lng': -73.57706914908198,
#         'postalCode': 'H3J 1K8',
#         'state': 'QC'},
#        'name': 'Comité d’éducation aux adultes de la Petite-Bourgogne et de Saint-Henri (CEDA)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dd2d9fb45dd45f719221a9f-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4dd2d9fb45dd45f719221a9f',
#        'location': {'address': '1800 Avenue McGill College',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3008,
#         'formattedAddress': ['1800 Avenue McGill College',
#          'Montréal QC H3A 3J6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.502516648679716,
#           'lng': -73.5725538824651}],
#         'lat': 45.502516648679716,
#         'lng': -73.5725538824651,
#         'postalCode': 'H3A 3J6',
#         'state': 'QC'},
#        'name': 'Cisco Systems',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52ea657c498eb6634502d05d-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '52ea657c498eb6634502d05d',
#        'location': {'cc': 'CA',
#         'country': 'Canada',
#         'distance': 3054,
#         'formattedAddress': ['Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.473467,
#           'lng': -73.590757}],
#         'lat': 45.473467,
#         'lng': -73.590757},
#        'name': 'Mission Bon Accueil',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56322f45498e62f33750ae4d-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '56322f45498e62f33750ae4d',
#        'location': {'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3057,
#         'formattedAddress': ['Montréal QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50402681296833,
#           'lng': -73.57240195822189}],
#         'lat': 45.50402681296833,
#         'lng': -73.57240195822189,
#         'state': 'QC'},
#        'name': 'Intact Lab',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4de63609c65b98fadaf5a4d2-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4de63609c65b98fadaf5a4d2',
#        'location': {'address': '2020 Robert-Bourassa Blvd',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'De Maisonneuve',
#         'distance': 3083,
#         'formattedAddress': ['2020 Robert-Bourassa Blvd (De Maisonneuve)',
#          'Montréal QC H3A 2A5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50399750071899,
#           'lng': -73.57204622469932}],
#         'lat': 45.50399750071899,
#         'lng': -73.57204622469932,
#         'postalCode': 'H3A 2A5',
#         'state': 'QC'},
#        'name': 'Intact Corporation Financière',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bcf20dffb84c9b616db243e-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4bcf20dffb84c9b616db243e',
#        'location': {'address': '111 Rue Duke',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'coin Wellington',
#         'distance': 4203,
#         'formattedAddress': ['111 Rue Duke (coin Wellington)',
#          'Montréal QC H3C 2M1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.4968335654365,
#           'lng': -73.55649091488851}],
#         'lat': 45.4968335654365,
#         'lng': -73.55649091488851,
#         'postalCode': 'H3C 2M1',
#         'state': 'QC'},
#        'name': 'SAP Canada',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b82e264f964a520eaea30e3-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b82e264f964a520eaea30e3',
#        'location': {'address': '493 rue Sherbrooke Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'coin Aylmer',
#         'distance': 3116,
#         'formattedAddress': ['493 rue Sherbrooke Ouest (coin Aylmer)',
#          'Montréal QC H3A 1B6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.5063920156225,
#           'lng': -73.57262849807739}],
#         'lat': 45.5063920156225,
#         'lng': -73.57262849807739,
#         'postalCode': 'H3A 1B6',
#         'state': 'QC'},
#        'name': 'Centraide du Grand Montréal',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b4cc6e9f964a52069be26e3-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b4cc6e9f964a52069be26e3',
#        'location': {'address': '1500 Robert-Bourassa',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'Ste-Catherine',
#         'distance': 3116,
#         'formattedAddress': ['1500 Robert-Bourassa (Ste-Catherine)',
#          'Montréal QC H3A 3S7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50397504723243,
#           'lng': -73.5716015978195}],
#         'lat': 45.50397504723243,
#         'lng': -73.5716015978195,
#         'postalCode': 'H3A 3S7',
#         'state': 'QC'},
#        'name': "L'Oréal Canada",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '63143545'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b83e290f964a520281531e3-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b83e290f964a520281531e3',
#        'location': {'address': '500, rue Sherbrooke Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'Entre rue Aylmer & City-Concillors',
#         'distance': 3118,
#         'formattedAddress': ['500, rue Sherbrooke Ouest (Entre rue Aylmer & City-Concillors)',
#          'Montréal QC H3A 3G6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.506196679173556,
#           'lng': -73.57250439226823}],
#         'lat': 45.506196679173556,
#         'lng': -73.57250439226823,
#         'postalCode': 'H3A 3G6',
#         'state': 'QC'},
#        'name': 'Siège social de Loto-Québec',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-506a11b3e4b0dcfc94c320b0-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '506a11b3e4b0dcfc94c320b0',
#        'location': {'address': '625 President Kennedy Avenue',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3127,
#         'formattedAddress': ['625 President Kennedy Avenue',
#          'Montréal QC H3A 1K2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50511888312202,
#           'lng': -73.57189669795214}],
#         'lat': 45.50511888312202,
#         'lng': -73.57189669795214,
#         'postalCode': 'H3A 1K2',
#         'state': 'QC'},
#        'name': 'OVH Hosting Inc.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b108de2f964a520b67223e3-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b108de2f964a520b67223e3',
#        'location': {'address': '1253 ave. McGill College, #150',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 3128,
#         'formattedAddress': ['1253 ave. McGill College, #150',
#          'Montréal QC H3B 2Y5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50180582040714,
#           'lng': -73.57081227552223}],
#         'lat': 45.50180582040714,
#         'lng': -73.57081227552223,
#         'postalCode': 'H3B 2Y5',
#         'state': 'QC'},
#        'name': 'Google Montréal',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b5077aef964a520302427e3-40',
# ...
#           'lng': -73.562599}],
#         'lat': 45.485144,
#         'lng': -73.562599,
#         'postalCode': 'H3K 0A7',
#         'state': 'QC'},
#        'name': 'Unity Technologies',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5601800a498e9c9587530c29-87',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '5601800a498e9c9587530c29',
#        'location': {'address': '7250 Mile End',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'De Castelneau',
#         'distance': 3971,
#         'formattedAddress': ['7250 Mile End (De Castelneau)',
#          'Montréal QC H2R 3A4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.53175016716313,
#           'lng': -73.62312415541219}],
#         'lat': 45.53175016716313,
#         'lng': -73.62312415541219,
#         'postalCode': 'H2R 3A4',
#         'state': 'QC'},
#        'name': 'TD Credit Cards Phone Channel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5328c01d498e61c05e009cbb-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '5328c01d498e61c05e009cbb',
#        'location': {'address': '250 rue saint Antoine Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4015,
#         'formattedAddress': ['250 rue saint Antoine Ouest',
#          'Montréal QC',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50378974320817,
#           'lng': -73.55975698731503}],
#         'lat': 45.50378974320817,
#         'lng': -73.55975698731503,
#         'state': 'QC'},
#        'name': 'Cinesite',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e20916c1495f18f03454e8e-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4e20916c1495f18f03454e8e',
#        'location': {'address': '8200 Boulevard Decarie',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4019,
#         'formattedAddress': ['8200 Boulevard Decarie',
#          'Montréal QC H4P 2N2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49868677233639,
#           'lng': -73.66183254481055}],
#         'lat': 45.49868677233639,
#         'lng': -73.66183254481055,
#         'postalCode': 'H4P 2N2',
#         'state': 'QC'},
#        'name': 'Silanis Technology Inc',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf1a55552bda593afccb1b7-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4bf1a55552bda593afccb1b7',
#        'location': {'address': '360 St. Jacques street',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4030,
#         'formattedAddress': ['360 St. Jacques street',
#          'Montréal QC',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50239695066456,
#           'lng': -73.55924136655901}],
#         'lat': 45.50239695066456,
#         'lng': -73.55924136655901,
#         'state': 'QC'},
#        'name': 'Telefilm Canada',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5361658e498e86153ca0b2c5-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '5361658e498e86153ca0b2c5',
#        'location': {'address': '368, rue Notre-Dame Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4049,
#         'formattedAddress': ['368, rue Notre-Dame Ouest',
#          'Montréal QC H2Y 1T9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50198866329445,
#           'lng': -73.55890846223501}],
#         'lat': 45.50198866329445,
#         'lng': -73.55890846223501,
#         'postalCode': 'H2Y 1T9',
#         'state': 'QC'},
#        'name': 'Uber Montréal',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd73b2e09ecb713cf6b467c-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4bd73b2e09ecb713cf6b467c',
#        'location': {'address': '8300 boul. Décarie',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4050,
#         'formattedAddress': ['8300 boul. Décarie',
#          'Montréal QC H4P 2P5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49965010856023,
#           'lng': -73.6621540722674}],
#         'lat': 45.49965010856023,
#         'lng': -73.6621540722674,
#         'postalCode': 'H4P 2P5',
#         'state': 'QC'},
#        'name': 'Le Château',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-541c80c2498e537b404e6573-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '541c80c2498e537b404e6573',
#        'location': {'address': '465 Rue St-Jean, Suite 601',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4161,
#         'formattedAddress': ['465 Rue St-Jean, Suite 601',
#          'Montréal QC H2Y 2R6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50289980702039,
#           'lng': -73.55764394504429}],
#         'lat': 45.50289980702039,
#         'lng': -73.55764394504429,
#         'postalCode': 'H2Y 2R6',
#         'state': 'QC'},
#        'name': '/N Spro - Montreal Office',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adba4f7f964a520b52921e3-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4adba4f7f964a520b52921e3',
#        'location': {'address': '7 rue Saint-Jacques Ouest',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4253,
#         'formattedAddress': ['7 rue Saint-Jacques Ouest',
#          'Montréal QC H2Y 1K9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.506351404866,
#           'lng': -73.55742476716472}],
#         'lat': 45.506351404866,
#         'lng': -73.55742476716472,
#         'postalCode': 'H2Y 1K9',
#         'state': 'QC'},
#        'name': 'La Presse',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '40061279'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52cd9bcc498e99d4869d56c6-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '52cd9bcc498e99d4869d56c6',
#        'location': {'address': '645 Wellington',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'distance': 4292,
#         'formattedAddress': ['645 Wellington', 'Montréal QC', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.498710648119946,
#           'lng': -73.55538666393367}],
#         'lat': 45.498710648119946,
#         'lng': -73.55538666393367,
#         'state': 'QC'},
#        'name': 'MPC',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d932178f10ea093cda4211e-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4d932178f10ea093cda4211e',
#        'location': {'address': '700 rue wellington',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'rue queen',
#         'distance': 4306,
#         'formattedAddress': ['700 rue wellington (rue queen)',
#          'Montréal QC H3C 2P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49805327407656,
#           'lng': -73.5551889979685}],
#         'lat': 45.49805327407656,
#         'lng': -73.5551889979685,
#         'postalCode': 'H3C 2P1',
#         'state': 'QC'},
#        'name': 'Morgan Stanley',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b96839cf964a5204ed134e3-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4b96839cf964a5204ed134e3',
#        'location': {'address': '5455, Avenue de Gaspé, bureau 440',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'Rue Saint-Viateur Ouest',
#         'distance': 4320,
#         'formattedAddress': ['5455, Avenue de Gaspé, bureau 440 (Rue Saint-Viateur Ouest)',
#          'Montréal QC H2T 3B3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50259266030826,
#           'lng': -73.55551816810323}],
#         'lat': 45.50259266030826,
#         'lng': -73.55551816810323,
#         'postalCode': 'H2T 3B3',
#         'state': 'QC'},
#        'name': 'Camden',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51e5649f498e1bf101acec7a-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '51e5649f498e1bf101acec7a',
#        'location': {'address': '2365 Chemin De La Côte De Liesse',
#         'cc': 'CA',
#         'city': 'Saint-Laurent',
#         'country': 'Canada',
#         'distance': 4424,
#         'formattedAddress': ['2365 Chemin De La Côte De Liesse',
#          'Saint-Laurent QC H4N 2M7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52239571399332,
#           'lng': -73.65425072653663}],
#         'lat': 45.52239571399332,
#         'lng': -73.65425072653663,
#         'postalCode': 'H4N 2M7',
#         'state': 'QC'},
#        'name': 'Saputo Head Office Canada',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dcaf231d4c0dfa030c5cf77-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '4dcaf231d4c0dfa030c5cf77',
#        'location': {'address': '888, boulevard de Maisonneuve Est',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'country': 'Canada',
#         'crossStreet': 'Place Dupuis - Tour 3',
#         'distance': 4520,
#         'formattedAddress': ['888, boulevard de Maisonneuve Est (Place Dupuis - Tour 3)',
#          'Montréal QC H2L 4S8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51673946088166,
#           'lng': -73.55955908554367}],
#         'lat': 45.51673946088166,
#         'lng': -73.55955908554367,
#         'postalCode': 'H2L 4S8',
#         'state': 'QC'},
#        'name': 'WB Games Montréal',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Montreal',
#   'headerLocation': 'Montreal',
#   'headerLocationGranularity': 'city',
#   'query': 'office',
#   'suggestedBounds': {'ne': {'lat': 45.56962997241407,
#     'lng': -73.50724772401036},
#    'sw': {'lat': 45.42480182758593, 'lng': -73.71348067598966}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 179}}

# %% [markdown]
# The resulting .json file was normalized and imported into a pandas dataframe.

# %%
offices = results['response']['groups'][0]['items']
    
nearby_offices_montreal = json_normalize(offices) 

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_offices_montreal =nearby_offices_montreal.loc[:, filtered_columns]

nearby_offices_montreal['venue.categories'] = nearby_offices_montreal.apply(get_category_type, axis=1)

nearby_offices_montreal.columns = [col.split(".")[-1] for col in nearby_offices_montreal.columns]

nearby_offices_montreal.tail()
# Out:
#                          name categories        lat        lng
# 95                        MPC     Office  45.498711 -73.555387
# 96             Morgan Stanley     Office  45.498053 -73.555189
# 97                     Camden     Office  45.502593 -73.555518
# 98  Saputo Head Office Canada     Office  45.522396 -73.654251
# 99          WB Games Montréal     Office  45.516739 -73.559559

# %%
nearby_offices_montreal.shape
# Out:
# (100, 4)

# %% [markdown]
# The resulting data frame show there are 100 potential customers within a five mile radius of the center of Montreal city.

# %% [markdown]
# ### Results of Part One

# %%
print('{} potential customers were returned by Foursquare in Montreal.'.format(nearby_offices_montreal.shape[0]))
print('{} potential customers were returned by Foursquare in Quebec.'.format(nearby_offices_quebec.shape[0]))
# Out:
# 100 potential customers were returned by Foursquare in Montreal.
# 43 potential customers were returned by Foursquare in Quebec.

# %% [markdown]
# ### Conclusion of Part One
#
# The city that should be analysed further is Montreal as it offers the greater number of potential customers for the client.

# %% [markdown]
# ## Part Two:
#
# ## In the city chosen in answer to part one, which city borough would offer the greatest catchment area for the business?
#
# ### Data Collection

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId=4bf58dd8d48988d124941735'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)

        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_offices = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_offices.columns = ['Borough', 
                  'Latitude', 
                  'Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_offices)

# %%
montreal_offices = getNearbyVenues(names=df_montreal['Borough'],
                                   latitudes=df_montreal['Latitude'],
                                   longitudes=df_montreal['Longitude']
                                    )
# Out:
# Ahuntsic-Cartierville
# Anjou
# Côte-des-Neiges–Notre-Dame-de-Grâce
# Lachine
# Lasalle
# Le Plateau-Mont-Royal
# Le Sud-Ouest
# L'Île-Bizard–Sainte-Geneviève
# Mercier–Hochelaga-Maisonneuve
# Montréal-Nord
# Outremont
# Pierrefonds-Roxboro
# Rivière-des-Prairies
# Rosemont–La Petite-Patrie
# Saint-Laurent
# Saint-Léonard
# Verdun
# Ville-Marie
# Villeray–Saint-Michel–Parc-Extension

# %%
print (montreal_offices.shape)
montreal_offices.head()
# Out:
# (67, 7)
#                                Borough  Latitude  Longitude  \
# 0                Ahuntsic-Cartierville  45.53856  -73.69266
# 1                Ahuntsic-Cartierville  45.53856  -73.69266
# 2                Ahuntsic-Cartierville  45.53856  -73.69266
# 3  Côte-des-Neiges–Notre-Dame-de-Grâce  45.49069  -73.63321
# 4                              Lachine  45.43665  -73.68510
#
#                                                Venue  Venue Latitude  \
# 0                                         OSHARA INC       45.536596
# 1  Peter K Photography - (Montreal Wedding Photog...       45.541345
# 2                           santé de pieds podologie       45.542016
# 3                                    TD Canada Trust       45.491823
# 4                           Vitrerie Chatelle/Simard       45.438562
#
#    Venue Longitude   Venue Category
# 0       -73.693092           Office
# 1       -73.695517           Office
# 2       -73.694763  Coworking Space
# 3       -73.631786           Office
# 4       -73.681563           Office

# %%
montreal_offices.groupby('Borough').count()
# Out:
#                                       Latitude  Longitude  Venue  \
# Borough
# Ahuntsic-Cartierville                        3          3      3
# Côte-des-Neiges–Notre-Dame-de-Grâce          1          1      1
# Lachine                                      5          5      5
# Lasalle                                      8          8      8
# Le Plateau-Mont-Royal                        6          6      6
# Montréal-Nord                                1          1      1
# Outremont                                    2          2      2
# Pierrefonds-Roxboro                          1          1      1
# Rosemont–La Petite-Patrie                   27         27     27
# Saint-Laurent                                4          4      4
# Verdun                                       6          6      6
# Ville-Marie                                  1          1      1
# Villeray–Saint-Michel–Parc-Extension         2          2      2
#
#                                       Venue Latitude  Venue Longitude  \
# Borough
# Ahuntsic-Cartierville                              3                3
# Côte-des-Neiges–Notre-Dame-de-Grâce                1                1
# Lachine                                            5                5
# Lasalle                                            8                8
# Le Plateau-Mont-Royal                              6                6
# Montréal-Nord                                      1                1
# Outremont                                          2                2
# Pierrefonds-Roxboro                                1                1
# Rosemont–La Petite-Patrie                         27               27
# Saint-Laurent                                      4                4
# Verdun                                             6                6
# Ville-Marie                                        1                1
# Villeray–Saint-Michel–Parc-Extension               2                2
#
#                                       Venue Category
# Borough
# Ahuntsic-Cartierville                              3
# Côte-des-Neiges–Notre-Dame-de-Grâce                1
# Lachine                                            5
# Lasalle                                            8
# Le Plateau-Mont-Royal                              6
# Montréal-Nord                                      1
# Outremont                                          2
# Pierrefonds-Roxboro                                1
# Rosemont–La Petite-Patrie                         27
# Saint-Laurent                                      4
# Verdun                                             6
# Ville-Marie                                        1
# Villeray–Saint-Michel–Parc-Extension               2

# %% [markdown]
# Analyze each Borough of Montreal

# %% [markdown]
# Segmenting and clustering boroughs in montreal by slicing the original and creating a new dataframe for  montreal borough data.

# %%
montreal_onehot = pd.get_dummies(montreal_offices[['Venue Category']], prefix="", prefix_sep="")

montreal_onehot['Borough'] = montreal_offices['Borough'] 

fixed_columns = [montreal_onehot.columns[-1]] + list(montreal_onehot.columns[:-1])
montreal_onehot = montreal_onehot[fixed_columns]

montreal_onehot.head()
# Out:
#                                Borough  Advertising Agency  Coworking Space  \
# 0                Ahuntsic-Cartierville                   0                0
# 1                Ahuntsic-Cartierville                   0                0
# 2                Ahuntsic-Cartierville                   0                1
# 3  Côte-des-Neiges–Notre-Dame-de-Grâce                   0                0
# 4                              Lachine                   0                0
#
#    Electronics Store  Office  Tech Startup
# 0                  0       1             0
# 1                  0       1             0
# 2                  0       0             0
# 3                  0       1             0
# 4                  0       1             0

# %%
montreal_grouped = montreal_onehot.groupby('Borough').mean().reset_index()
montreal_grouped
# Out:
#                                  Borough  Advertising Agency  Coworking Space  \
# 0                  Ahuntsic-Cartierville            0.000000         0.333333
# 1    Côte-des-Neiges–Notre-Dame-de-Grâce            0.000000         0.000000
# 2                                Lachine            0.000000         0.200000
# 3                                Lasalle            0.000000         0.000000
# 4                  Le Plateau-Mont-Royal            0.000000         0.666667
# 5                          Montréal-Nord            0.000000         0.000000
# 6                              Outremont            0.000000         0.500000
# 7                    Pierrefonds-Roxboro            0.000000         0.000000
# 8              Rosemont–La Petite-Patrie            0.037037         0.148148
# 9                          Saint-Laurent            0.250000         0.000000
# 10                                Verdun            0.166667         0.166667
# 11                           Ville-Marie            0.000000         0.000000
# 12  Villeray–Saint-Michel–Parc-Extension            0.500000         0.000000
#
#     Electronics Store    Office  Tech Startup
# 0            0.000000  0.666667      0.000000
# 1            0.000000  1.000000      0.000000
# 2            0.000000  0.800000      0.000000
# 3            0.000000  1.000000      0.000000
# 4            0.000000  0.333333      0.000000
# 5            0.000000  1.000000      0.000000
# 6            0.000000  0.500000      0.000000
# 7            0.000000  1.000000      0.000000
# 8            0.037037  0.703704      0.074074
# 9            0.000000  0.750000      0.000000
# 10           0.000000  0.500000      0.166667
# 11           0.000000  1.000000      0.000000
# 12           0.000000  0.500000      0.000000

# %%
montreal_grouped.shape
# Out:
# (13, 6)

# %% [markdown]
# Print each Borough with its 5 most common venues.

# %%
num_top_offices = 5

for Borough in montreal_grouped['Borough']:
    print("----"+Borough+"----")
    temp = montreal_grouped[montreal_grouped['Borough'] == Borough].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_offices))
    print('\n')
# Out:
# ----Ahuntsic-Cartierville----
#                 venue  freq
# 0              Office  0.67
# 1     Coworking Space  0.33
# 2  Advertising Agency  0.00
# 3   Electronics Store  0.00
# 4        Tech Startup  0.00
#
#
# ----Côte-des-Neiges–Notre-Dame-de-Grâce----
#                 venue  freq
# 0              Office   1.0
# 1  Advertising Agency   0.0
# 2     Coworking Space   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0
#
#
# ----Lachine----
#                 venue  freq
# 0              Office   0.8
# 1     Coworking Space   0.2
# 2  Advertising Agency   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0
#
#
# ----Lasalle----
#                 venue  freq
# 0              Office   1.0
# 1  Advertising Agency   0.0
# 2     Coworking Space   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0
#
#
# ----Le Plateau-Mont-Royal----
#                 venue  freq
# 0     Coworking Space  0.67
# 1              Office  0.33
# 2  Advertising Agency  0.00
# 3   Electronics Store  0.00
# 4        Tech Startup  0.00
#
#
# ----Montréal-Nord----
#                 venue  freq
# 0              Office   1.0
# 1  Advertising Agency   0.0
# 2     Coworking Space   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0
#
#
# ----Outremont----
#                 venue  freq
# 0     Coworking Space   0.5
# 1              Office   0.5
# 2  Advertising Agency   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0
#
#
# ----Pierrefonds-Roxboro----
#                 venue  freq
# 0              Office   1.0
# 1  Advertising Agency   0.0
# 2     Coworking Space   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0
#
#
# ----Rosemont–La Petite-Patrie----
#                 venue  freq
# 0              Office  0.70
# 1     Coworking Space  0.15
# 2        Tech Startup  0.07
# 3  Advertising Agency  0.04
# 4   Electronics Store  0.04
#
#
# ----Saint-Laurent----
#                 venue  freq
# 0              Office  0.75
# 1  Advertising Agency  0.25
# 2     Coworking Space  0.00
# 3   Electronics Store  0.00
# 4        Tech Startup  0.00
#
#
# ----Verdun----
#                 venue  freq
# 0              Office  0.50
# 1  Advertising Agency  0.17
# 2     Coworking Space  0.17
# 3        Tech Startup  0.17
# 4   Electronics Store  0.00
#
#
# ----Ville-Marie----
#                 venue  freq
# 0              Office   1.0
# 1  Advertising Agency   0.0
# 2     Coworking Space   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0
#
#
# ----Villeray–Saint-Michel–Parc-Extension----
#                 venue  freq
# 0  Advertising Agency   0.5
# 1              Office   0.5
# 2     Coworking Space   0.0
# 3   Electronics Store   0.0
# 4        Tech Startup   0.0

# %% [markdown]
# ##### Place this into a pandas dataframe in descending order, display the top 3 venues for each neighbourhood.

# %%
def return_most_common_venues(row, num_top_offices):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_offices]

# %%
num_top_offices = 3

indicators = ['st', 'nd', 'rd']

columns = ['Borough']
for ind in np.arange(num_top_offices):
    try:
        columns.append('{}{} Most Common Office'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Office'.format(ind+1))

boroughs_offices_sorted = pd.DataFrame(columns=columns)
boroughs_offices_sorted['Borough'] = montreal_grouped['Borough']

for ind in np.arange(montreal_grouped.shape[0]):
    boroughs_offices_sorted.iloc[ind, 1:] = return_most_common_venues(montreal_grouped.iloc[ind, :], num_top_offices)

boroughs_offices_sorted.head()
# Out:
#                                Borough 1st Most Common Office  \
# 0                Ahuntsic-Cartierville                 Office
# 1  Côte-des-Neiges–Notre-Dame-de-Grâce                 Office
# 2                              Lachine                 Office
# 3                              Lasalle                 Office
# 4                Le Plateau-Mont-Royal        Coworking Space
#
#   2nd Most Common Office 3rd Most Common Office
# 0        Coworking Space           Tech Startup
# 1           Tech Startup      Electronics Store
# 2        Coworking Space           Tech Startup
# 3           Tech Startup      Electronics Store
# 4                 Office           Tech Startup

# %% [markdown]
# Now running k-means to cluster the neighbourhoods into 5 clusters. Then create a new dataframe to include the cluster.

# %%
kclusters = 5

montreal_grouped_clustering = montreal_grouped.drop('Borough', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(montreal_grouped_clustering)

kmeans.labels_[0:10]
# Out:
# array([3, 0, 3, 0, 1, 0, 1, 0, 3, 4], dtype=int32)

# %%
boroughs_offices_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

montreal_merged = montreal_offices

montreal_merged = montreal_merged.join(boroughs_offices_sorted.set_index('Borough'), on='Borough',how='right')

montreal_merged.head()
# Out:
#                                Borough  Latitude  Longitude  \
# 0                Ahuntsic-Cartierville  45.53856  -73.69266
# 1                Ahuntsic-Cartierville  45.53856  -73.69266
# 2                Ahuntsic-Cartierville  45.53856  -73.69266
# 3  Côte-des-Neiges–Notre-Dame-de-Grâce  45.49069  -73.63321
# 4                              Lachine  45.43665  -73.68510
#
#                                                Venue  Venue Latitude  \
# 0                                         OSHARA INC       45.536596
# 1  Peter K Photography - (Montreal Wedding Photog...       45.541345
# 2                           santé de pieds podologie       45.542016
# 3                                    TD Canada Trust       45.491823
# 4                           Vitrerie Chatelle/Simard       45.438562
#
#    Venue Longitude   Venue Category  Cluster Labels 1st Most Common Office  \
# 0       -73.693092           Office               3                 Office
# 1       -73.695517           Office               3                 Office
# 2       -73.694763  Coworking Space               3                 Office
# 3       -73.631786           Office               0                 Office
# 4       -73.681563           Office               3                 Office
#
#   2nd Most Common Office 3rd Most Common Office
# 0        Coworking Space           Tech Startup
# 1        Coworking Space           Tech Startup
# 2        Coworking Space           Tech Startup
# 3           Tech Startup      Electronics Store
# 4        Coworking Space           Tech Startup

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(montreal_merged['Latitude'], montreal_merged['Longitude'], montreal_merged['Borough'], montreal_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Examine clusters and determine discriminating potential customer categories for each cluster - assigning a name to each cluster

# %% [markdown]
# #### Cluster 1: Tech Startup

# %%
montreal_merged.loc[montreal_merged['Cluster Labels'] == 0, montreal_merged.columns[[1] + list(range(5, montreal_merged.shape[1]))]]
# Out:
#      Latitude  Venue Longitude Venue Category  Cluster Labels  \
# 3   45.490690       -73.631786         Office               0
# 9   45.438900       -73.622861         Office               0
# 10  45.438900       -73.622590         Office               0
# 11  45.438900       -73.626532         Office               0
# 12  45.438900       -73.621579         Office               0
# 13  45.438900       -73.623903         Office               0
# 14  45.438900       -73.620129         Office               0
# 15  45.438900       -73.629718         Office               0
# 16  45.438900       -73.631015         Office               0
# 23  45.593899       -73.634813         Office               0
# 26  45.495508       -73.850580         Office               0
# 64  47.332308       -79.437268         Office               0
#
#    1st Most Common Office 2nd Most Common Office 3rd Most Common Office
# 3                  Office           Tech Startup      Electronics Store
# 9                  Office           Tech Startup      Electronics Store
# 10                 Office           Tech Startup      Electronics Store
# 11                 Office           Tech Startup      Electronics Store
# 12                 Office           Tech Startup      Electronics Store
# 13                 Office           Tech Startup      Electronics Store
# 14                 Office           Tech Startup      Electronics Store
# 15                 Office           Tech Startup      Electronics Store
# 16                 Office           Tech Startup      Electronics Store
# 23                 Office           Tech Startup      Electronics Store
# 26                 Office           Tech Startup      Electronics Store
# 64                 Office           Tech Startup      Electronics Store

# %% [markdown]
# #### Cluster 2: Coworking Space/ Tech Startup

# %%
montreal_merged.loc[montreal_merged['Cluster Labels'] == 1, montreal_merged.columns[[1] + list(range(5, montreal_merged.shape[1]))]]
# Out:
#      Latitude  Venue Longitude   Venue Category  Cluster Labels  \
# 17  45.530210       -73.587025           Office               1
# 18  45.530210       -73.587155           Office               1
# 19  45.530210       -73.584759  Coworking Space               1
# 20  45.530210       -73.578515  Coworking Space               1
# 21  45.530210       -73.579640  Coworking Space               1
# 22  45.530210       -73.579936  Coworking Space               1
# 24  45.518617       -73.608387           Office               1
# 25  45.518617       -73.602905  Coworking Space               1
#
#    1st Most Common Office 2nd Most Common Office 3rd Most Common Office
# 17        Coworking Space                 Office           Tech Startup
# 18        Coworking Space                 Office           Tech Startup
# 19        Coworking Space                 Office           Tech Startup
# 20        Coworking Space                 Office           Tech Startup
# 21        Coworking Space                 Office           Tech Startup
# 22        Coworking Space                 Office           Tech Startup
# 24                 Office        Coworking Space           Tech Startup
# 25                 Office        Coworking Space           Tech Startup

# %% [markdown]
# #### Cluster 3: Tech Startup/ Coworking Space

# %%
montreal_merged.loc[montreal_merged['Cluster Labels'] == 2, montreal_merged.columns[[1] + list(range(5, montreal_merged.shape[1]))]]
# Out:
#      Latitude  Venue Longitude      Venue Category  Cluster Labels  \
# 58  45.460389       -73.563123              Office               2
# 59  45.460389       -73.563616              Office               2
# 60  45.460389       -73.566862              Office               2
# 61  45.460389       -73.563102     Coworking Space               2
# 62  45.460389       -73.562706        Tech Startup               2
# 63  45.460389       -73.568766  Advertising Agency               2
#
#    1st Most Common Office 2nd Most Common Office 3rd Most Common Office
# 58                 Office           Tech Startup        Coworking Space
# 59                 Office           Tech Startup        Coworking Space
# 60                 Office           Tech Startup        Coworking Space
# 61                 Office           Tech Startup        Coworking Space
# 62                 Office           Tech Startup        Coworking Space
# 63                 Office           Tech Startup        Coworking Space

# %% [markdown]
# #### Cluster 4: Coworking/ Tech Startup

# %%
montreal_merged.loc[montreal_merged['Cluster Labels'] == 3, montreal_merged.columns[[1] + list(range(5, montreal_merged.shape[1]))]]
# Out:
#      Latitude  Venue Longitude      Venue Category  Cluster Labels  \
# 0   45.538560       -73.693092              Office               3
# 1   45.538560       -73.695517              Office               3
# 2   45.538560       -73.694763     Coworking Space               3
# 4   45.436650       -73.681563              Office               3
# 5   45.436650       -73.682269              Office               3
# 6   45.436650       -73.690605              Office               3
# 7   45.436650       -73.683516     Coworking Space               3
# 8   45.436650       -73.681848              Office               3
# 27  45.531567       -73.599026              Office               3
# 28  45.531567       -73.598421              Office               3
# 29  45.531567       -73.598641              Office               3
# 30  45.531567       -73.597508              Office               3
# 31  45.531567       -73.596386              Office               3
# 32  45.531567       -73.603017              Office               3
# 33  45.531567       -73.596758              Office               3
# 34  45.531567       -73.596854              Office               3
# 35  45.531567       -73.603105              Office               3
# 36  45.531567       -73.597240              Office               3
# 37  45.531567       -73.596552              Office               3
# 38  45.531567       -73.598069              Office               3
# 39  45.531567       -73.598134              Office               3
# 40  45.531567       -73.596160              Office               3
# 41  45.531567       -73.595443              Office               3
# 42  45.531567       -73.598608     Coworking Space               3
# 43  45.531567       -73.597613   Electronics Store               3
# 44  45.531567       -73.598089     Coworking Space               3
# 45  45.531567       -73.597848     Coworking Space               3
# 46  45.531567       -73.598168        Tech Startup               3
# 47  45.531567       -73.597495              Office               3
# 48  45.531567       -73.596733     Coworking Space               3
# 49  45.531567       -73.597984        Tech Startup               3
# 50  45.531567       -73.598163              Office               3
# 51  45.531567       -73.598202              Office               3
# 52  45.531567       -73.602968  Advertising Agency               3
# 53  45.531567       -73.597818              Office               3
#
#    1st Most Common Office 2nd Most Common Office 3rd Most Common Office
# 0                  Office        Coworking Space           Tech Startup
# 1                  Office        Coworking Space           Tech Startup
# 2                  Office        Coworking Space           Tech Startup
# 4                  Office        Coworking Space           Tech Startup
# 5                  Office        Coworking Space           Tech Startup
# 6                  Office        Coworking Space           Tech Startup
# 7                  Office        Coworking Space           Tech Startup
# 8                  Office        Coworking Space           Tech Startup
# 27                 Office        Coworking Space           Tech Startup
# 28                 Office        Coworking Space           Tech Startup
# 29                 Office        Coworking Space           Tech Startup
# 30                 Office        Coworking Space           Tech Startup
# 31                 Office        Coworking Space           Tech Startup
# 32                 Office        Coworking Space           Tech Startup
# 33                 Office        Coworking Space           Tech Startup
# 34                 Office        Coworking Space           Tech Startup
# 35                 Office        Coworking Space           Tech Startup
# 36                 Office        Coworking Space           Tech Startup
# 37                 Office        Coworking Space           Tech Startup
# 38                 Office        Coworking Space           Tech Startup
# 39                 Office        Coworking Space           Tech Startup
# 40                 Office        Coworking Space           Tech Startup
# 41                 Office        Coworking Space           Tech Startup
# 42                 Office        Coworking Space           Tech Startup
# 43                 Office        Coworking Space           Tech Startup
# 44                 Office        Coworking Space           Tech Startup
# 45                 Office        Coworking Space           Tech Startup
# 46                 Office        Coworking Space           Tech Startup
# 47                 Office        Coworking Space           Tech Startup
# 48                 Office        Coworking Space           Tech Startup
# 49                 Office        Coworking Space           Tech Startup
# 50                 Office        Coworking Space           Tech Startup
# 51                 Office        Coworking Space           Tech Startup
# 52                 Office        Coworking Space           Tech Startup
# 53                 Office        Coworking Space           Tech Startup

# %% [markdown]
# #### Cluster 5: Advertising Agency / Tech Startup

# %%
montreal_merged.loc[montreal_merged['Cluster Labels'] == 4, montreal_merged.columns[[1] + list(range(5, montreal_merged.shape[1]))]]
# Out:
#      Latitude  Venue Longitude      Venue Category  Cluster Labels  \
# 54  45.503270       -73.722579              Office               4
# 55  45.503270       -73.720534              Office               4
# 56  45.503270       -73.730129              Office               4
# 57  45.503270       -73.727789  Advertising Agency               4
# 65  45.537006       -73.624193              Office               4
# 66  45.537006       -73.624480  Advertising Agency               4
#
#    1st Most Common Office 2nd Most Common Office 3rd Most Common Office
# 54                 Office     Advertising Agency           Tech Startup
# 55                 Office     Advertising Agency           Tech Startup
# 56                 Office     Advertising Agency           Tech Startup
# 57                 Office     Advertising Agency           Tech Startup
# 65                 Office     Advertising Agency           Tech Startup
# 66                 Office     Advertising Agency           Tech Startup

# %% [markdown]
# ### Results of Part Two
#
# Cluster 4: This cluster contains the greatest concentration of potential customers for the client. Potential customers are in the form of Tech Startups and Co-working Offices. Both customer types come within the small/ medium office size the client prefers to service and they would require office supplies on a regular basis.
#
# Cluster 4 consists of two boroughs which are Villeray–Saint-Michel–Parc-Extension and Saint-Laurent.

# %% [markdown]
# ### Conclusion of Part Two
#
# The city borough which would offer the greatest catchment area for the clients business is Villeray–Saint-Michel–Parc-Extension. I have chosen this borough out of the two possibles given by the data analysis because of its close proximity to two other cluster centers. The 2nd option while having a large concentration of potential customers is isolated and would reduce opportunities for future business growth.

# %% [markdown]
# # Conclusion of Data Analysis
#
# After data collection, cleaning and analysis I can answer the initial data science problem posed in the introduction of this project.
#
# Part One: Which out of two possible locations (Quebec and Montreal) has the greater number of potential customers?
# Solution: Montreal as it offers the greater number of potential customers for the client.
#
# Part Two: In the city chosen in answer to part one, in this case Montreal, which city borough would offer the greatest catchment area for the business?
# Solution: The city borough of Montreal which would offer the greatest catchment area for the clients business is Villeray–Saint-Michel–Parc-Extension.
